# %%
# !pip install python-pptx
# !pip install openai
# Out:
# Requirement already satisfied: python-pptx in c:\users\suhas.g\appdata\local\programs\python\python311\lib\site-packages (0.6.23)
# Requirement already satisfied: lxml>=3.1.0 in c:\users\suhas.g\appdata\local\programs\python\python311\lib\site-packages (from python-pptx) (4.9.2)
# Requirement already satisfied: Pillow>=3.3.2 in c:\users\suhas.g\appdata\local\programs\python\python311\lib\site-packages (from python-pptx) (10.1.0)
# Requirement already satisfied: XlsxWriter>=0.5.7 in c:\users\suhas.g\appdata\local\programs\python\python311\lib\site-packages (from python-pptx) (3.2.0)
# Collecting openai
#   Downloading openai-1.37.0-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\suhas.g\appdata\local\programs\python\python311\lib\site-packages (from openai) (3.6.2)
# Collecting distro<2,>=1.7.0 (from openai)
#   Downloading distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting httpx<1,>=0.23.0 (from openai)
#   Downloading httpx-0.27.0-py3-none-any.whl.metadata (7.2 kB)
# Collecting pydantic<3,>=1.9.0 (from openai)
#   Downloading pydantic-2.8.2-py3-none-any.whl.metadata (125 kB)
#      ---------------------------------------- 0.0/125.2 kB ? eta -:--:--
#      -------------------------------------- 125.2/125.2 kB 3.6 MB/s eta 0:00:00
# Requirement already satisfied: sniffio in c:\users\suhas.g\appdata\local\programs\python\python311\lib\site-packages (from openai) (1.3.0)
# Requirement already satisfied: tqdm>4 in c:\users\suhas.g\appdata\local\programs\python\python311\lib\site-packages (from openai) (4.66.1)
# Requirement already satisfied: typing-extensions<5,>=4.7 in c:\users\suhas.g\appdata\local\programs\python\python311\lib\site-packages (from openai) (4.9.0)
# Requirement already satisfied: idna>=2.8 in c:\users\suhas.g\appdata\local\programs\python\python311\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.4)
# Requirement already satisfied: certifi in c:\users\suhas.g\appdata\local\programs\python\python311\lib\site-packages (from httpx<1,>=0.23.0->openai) (2023.5.7)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai)
#   Downloading httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->openai)
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting annotated-types>=0.4.0 (from pydantic<3,>=1.9.0->openai)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.20.1 (from pydantic<3,>=1.9.0->openai)
#   Downloading pydantic_core-2.20.1-cp311-none-win_amd64.whl.metadata (6.7 kB)
# Requirement already satisfied: colorama in c:\users\suhas.g\appdata\local\programs\python\python311\lib\site-packages (from tqdm>4->openai) (0.4.6)
# Downloading openai-1.37.0-py3-none-any.whl (337 kB)
#    ---------------------------------------- 0.0/337.0 kB ? eta -:--:--
#    --------------------------------------- 337.0/337.0 kB 20.4 MB/s eta 0:00:00
# Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#    ---------------------------------------- 0.0/75.6 kB ? eta -:--:--
#    ---------------------------------------- 75.6/75.6 kB ? eta 0:00:00
# Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#    ---------------------------------------- 0.0/77.9 kB ? eta -:--:--
#    ---------------------------------------- 77.9/77.9 kB ? eta 0:00:00
# Downloading pydantic-2.8.2-py3-none-any.whl (423 kB)
#    ---------------------------------------- 0.0/423.9 kB ? eta -:--:--
#    ---------------------------------------- 423.9/423.9 kB 8.8 MB/s eta 0:00:00
# Downloading pydantic_core-2.20.1-cp311-none-win_amd64.whl (1.9 MB)
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.9 MB 10.6 MB/s eta 0:00:01
#    ---------- ----------------------------- 0.5/1.9 MB 6.6 MB/s eta 0:00:01
#    ------------- -------------------------- 0.6/1.9 MB 5.8 MB/s eta 0:00:01
#    ------------- -------------------------- 0.6/1.9 MB 5.8 MB/s eta 0:00:01
#    ------------- -------------------------- 0.6/1.9 MB 5.8 MB/s eta 0:00:01
#    -------------------------- ------------- 1.3/1.9 MB 4.5 MB/s eta 0:00:01
#    ------------------------------ --------- 1.5/1.9 MB 4.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.6/1.9 MB 4.4 MB/s eta 0:00:01
#    ------------------------------------- -- 1.8/1.9 MB 4.2 MB/s eta 0:00:01
#    ---------------------------------------  1.9/1.9 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------------  1.9/1.9 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------- 1.9/1.9 MB 3.6 MB/s eta 0:00:00
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ---------------------------------------- 0.0/58.3 kB ? eta -:--:--
#    ---------------------------------------- 58.3/58.3 kB 3.2 MB/s eta 0:00:00
# Installing collected packages: pydantic-core, h11, distro, annotated-types, pydantic, httpcore, httpx, openai
# Successfully installed annotated-types-0.7.0 distro-1.9.0 h11-0.14.0 httpcore-1.0.5 httpx-0.27.0 openai-1.37.0 pydantic-2.8.2 pydantic-core-2.20.1

# %%
from pptx import Presentation

# %%
master=Presentation("updated-master.pptx")

# %%
def get_slide_placeholders(slide,a):
    for shape in slide.placeholders:
     print('%d %s' % (shape.placeholder_format.idx, shape.name))

# %%
def get_child_layouts(layout,a):
    for i, slide_layout in enumerate(layout.slide_layouts):
           print(f"Layout {i}: {(slide_layout.name)}")
           get_slide_placeholders(slide_layout,a)

# %%
a={}
def get_master_layout(master):
    for i, layout in enumerate(master.slide_masters):
      # print("New Master Layout")
      # print(f"Layout {i}: {(layout.slide_layouts)}")
      get_child_layouts(layout,a)

get_master_layout(master)
# Out:
# Layout 0: 1_Titolo e contenuto
# Layout 1: Diapositiva titolo
# 10 Text Placeholder 6
# Layout 2: 3_Layout personalizzato
# 10 Text Placeholder 3
# Layout 3: 4_Layout personalizzato
# 10 Text Placeholder 5
# Layout 4: 5_Layout personalizzato
# 10 Text Placeholder 5
# Layout 5: 6_Layout personalizzato
# 10 Text Placeholder 7
# Layout 6: 7_Layout personalizzato
# 10 Text Placeholder 10
# Layout 7: Titolo e contenuto
# Layout 8: Layout personalizzato
# Layout 0: 1_Diapositiva titolo
# 0 Segnaposto titolo 1
# 4 Segnaposto numero diapositiva 5
# 10 Text Placeholder 4
# Layout 1: 2_Diapositiva titolo
# 0 Segnaposto titolo 1
# 1 Segnaposto testo 2
# 4 Segnaposto numero diapositiva 5
# Layout 2: 4_Diapositiva titolo
# 0 Segnaposto titolo 1
# 13 Segnaposto testo 2
# 4 Segnaposto numero diapositiva 5
# Layout 3: 5_Diapositiva titolo
# 0 Segnaposto titolo 1
# 13 Segnaposto testo 2
# 4 Segnaposto numero diapositiva 5
# Layout 4: 3_Diapositiva titolo
# 0 Segnaposto titolo 1
# 4 Segnaposto numero diapositiva 5
# Layout 5: 1_Titolo e contenuto
# 0 Segnaposto titolo 1
# 4 Segnaposto numero diapositiva 5
# Layout 6: Layout personalizzato
# 4 Segnaposto numero diapositiva 5
# 10 Text Placeholder 8
# Layout 0: 1_Diapositiva titolo
# 0 Segnaposto titolo 1
# 1 Segnaposto testo 2
# 4 Segnaposto numero diapositiva 5
# Layout 1: 2_Diapositiva titolo
# 0 Segnaposto titolo 1
# 1 Segnaposto testo 2
# 4 Segnaposto numero diapositiva 5
# Layout 2: 3_Diapositiva titolo
# 0 Segnaposto titolo 1
# 4 Segnaposto numero diapositiva 5
# Layout 3: Titolo e contenuto
# 0 Segnaposto titolo 1
# 1 Segnaposto testo 2
# 4 Segnaposto numero diapositiva 5
# Layout 4: 1_Titolo e contenuto
# 0 Segnaposto titolo 1
# 4 Segnaposto numero diapositiva 5
# Layout 5: Layout personalizzato
# 4 Segnaposto numero diapositiva 5
# Layout 0: 1_Diapositiva titolo
# 4 Segnaposto numero diapositiva 5
# Layout 0: 1_Diapositiva titolo
# 0 Segnaposto titolo 1
# 1 Segnaposto testo 2
# 4 Segnaposto numero diapositiva 5
# Layout 1: 2_Diapositiva titolo
# 0 Segnaposto titolo 1
# 1 Segnaposto testo 2
# 4 Segnaposto numero diapositiva 5
# Layout 2: 3_Diapositiva titolo
# 0 Segnaposto titolo 1
# 4 Segnaposto numero diapositiva 5
# Layout 3: Titolo e contenuto
# 0 Segnaposto titolo 1
# 1 Segnaposto testo 2
# 4 Segnaposto numero diapositiva 5
# Layout 4: 1_Titolo e contenuto
# 0 Segnaposto titolo 1
# 4 Segnaposto numero diapositiva 5
# Layout 5: Layout personalizzato
# 4 Segnaposto numero diapositiva 5
# Layout 0: Layout personalizzato
# 0 Titolo 1
# Layout 0: Layout personalizzato
# 0 Titolo 1
# 4 Segnaposto numero diapositiva 5
# Layout 0: 1_Diapositiva titolo
# 0 Segnaposto titolo 1
# 1 Segnaposto testo 2
# 4 Segnaposto numero diapositiva 5
# Layout 1: 2_Diapositiva titolo
# 0 Segnaposto titolo 1
# 1 Segnaposto testo 2
# 4 Segnaposto numero diapositiva 5
# Layout 2: 3_Diapositiva titolo
# 0 Segnaposto titolo 1
# 4 Segnaposto numero diapositiva 5
# Layout 3: Titolo e contenuto
# 0 Segnaposto titolo 1
# 1 Segnaposto testo 2
# 4 Segnaposto numero diapositiva 5
# Layout 4: 1_Titolo e contenuto
# 0 Segnaposto titolo 1
# 4 Segnaposto numero diapositiva 5
# Layout 0: 1_Diapositiva titolo
# 0 Segnaposto titolo 1
# 1 Segnaposto testo 2
# 4 Segnaposto numero diapositiva 5
# Layout 1: 2_Diapositiva titolo
# 0 Segnaposto titolo 1
# 1 Segnaposto testo 2
# 4 Segnaposto numero diapositiva 5
# Layout 2: 3_Diapositiva titolo
# 0 Segnaposto titolo 1
# 4 Segnaposto numero diapositiva 5
# Layout 0: Diapositiva titolo
# 0 Segnaposto titolo 4
# 4 Segnaposto numero diapositiva 5

# %%
def get_master_layout(master):
    for i, layout in enumerate(master.slide_masters):
      print("New Master Layout")
      # print(f"Layout {i}: {(layout)}")

get_master_layout(master)
# Out:
# New Master Layout
# New Master Layout
# New Master Layout
# New Master Layout
# New Master Layout
# New Master Layout
# New Master Layout
# New Master Layout
# New Master Layout
# New Master Layout

# %%
# print(master.slide_masters.element.xml)

# %%
# Inside a layout slides can be picked up randomly
a=[]

# %%
def get_slide_placeholders(slide):
    placeholders={   
    }
    for shape in slide.placeholders:
        placeholders[shape.name]=shape.placeholder_format.idx
     
        # print('%d %s' % (shape.placeholder_format.idx, shape.name))
    return placeholders

# %%
def get_child_layouts(layout):
    new_layout={}
    slides=[]
    for i, slide_layout in enumerate(layout.slide_layouts):
           # print(f"Layout {i}: {(slide_layout.name)}")
           # placeholders=
           
           c=get_slide_placeholders(slide_layout)
           slides.append({"id":i,"slide_obj":slide_layout,"placeholders":c})
           # print(c)
    # new_layout["slides"]=slides
    return slides

# %%
def get_master_layout(master):
    for i, layout in enumerate(master.slide_masters):
      
      print("New Master Layout")
      # print(f"Layout {i}: {(layout.slide_layouts)}")
      b=get_child_layouts(layout)
      slide_layout={"layout_id": i,
                    "slides":b
                   }
        
      # print(slide_layout)
      a.append(slide_layout)

get_master_layout(master)
# print(a)
# Out:
# New Master Layout
# New Master Layout
# New Master Layout
# New Master Layout
# New Master Layout
# New Master Layout
# New Master Layout
# New Master Layout
# New Master Layout
# New Master Layout

# %%
#  Mapping for layout types

# %%
slide_layouts_type={
    "intro":0,
    "content_1":1,
    "content_2":2,
    "content_3":3,
    "content_4":4,
    "content_5":5,
    "content_6":6,
    "content_7":7,
    "content_8":8,
    "content_9":9
}

# %%
#  Sample Gpt Content

# %%
dummy=[]
dummy.append(a[1])
dummy
a
# Out:
# [{'layout_id': 0,
#   'slides': [{'id': 0,
#     'slide_obj': <pptx.slide.SlideLayout at 0x2cf83578d50>,
#     'placeholders': {}},
#    {'id': 1,
#     'slide_obj': <pptx.slide.SlideLayout at 0x2cf83569110>,
#     'placeholders': {'Text Placeholder 6': 10}},
#    {'id': 2,
#     'slide_obj': <pptx.slide.SlideLayout at 0x2cf82dba350>,
#     'placeholders': {'Text Placeholder 3': 10}},
#    {'id': 3,
#     'slide_obj': <pptx.slide.SlideLayout at 0x2cf835b3290>,
#     'placeholders': {'Text Placeholder 5': 10}},
#    {'id': 4,
#     'slide_obj': <pptx.slide.SlideLayout at 0x2cf8356b550>,
#     'placeholders': {'Text Placeholder 5': 10}},
#    {'id': 5,
#     'slide_obj': <pptx.slide.SlideLayout at 0x2cf83579110>,
#     'placeholders': {'Text Placeholder 7': 10}},
#    {'id': 6,
#     'slide_obj': <pptx.slide.SlideLayout at 0x2cf83578ed0>,
#     'placeholders': {'Text Placeholder 10': 10}},
#    {'id': 7,
#     'slide_obj': <pptx.slide.SlideLayout at 0x2cf83578f10>,
#     'placeholders': {}},
#    {'id': 8,
#     'slide_obj': <pptx.slide.SlideLayout at 0x2cf83579210>,
#     'placeholders': {}}]},
#  {'layout_id': 1,
#   'slides': [{'id': 0,
#     'slide_obj': <pptx.slide.SlideLayout at 0x2cf83578cd0>,
#     'placeholders': {'Segnaposto titolo 1': 0,
#      'Segnaposto numero diapositiva 5': 4,
#      'Text Placeholder 4': 10}},
#    {'id': 1,
#     'slide_obj': <pptx.slide.SlideLayout at 0x2cf83578e90>,
#     'placeholders': {'Segnaposto titolo 1': 0,
#      'Segnaposto testo 2': 1,
#      'Segnaposto numero diapositiva 5': 4}},
#    {'id': 2,
#     'slide_obj': <pptx.slide.SlideLayout at 0x2cf83579450>,
#     'placeholders': {'Segnaposto titolo 1': 0,
#      'Segnaposto testo 2': 13,
#      'Segnaposto numero diapositiva 5': 4}},
#    {'id': 3,
#     'slide_obj': <pptx.slide.SlideLayout at 0x2cf83579510>,
#     'placeholders': {'Segnaposto titolo 1': 0,
#      'Segnaposto testo 2': 13,
#      'Segnaposto numero diapositiva 5': 4}},
#    {'id': 4,
#     'slide_obj': <pptx.slide.SlideLayout at 0x2cf835795d0>,
#     'placeholders': {'Segnaposto titolo 1': 0,
#      'Segnaposto numero diapositiva 5': 4}},
#    {'id': 5,
#     'slide_obj': <pptx.slide.SlideLayout at 0x2cf83579690>,
#     'placeholders': {'Segnaposto titolo 1': 0,
#      'Segnaposto numero diapositiva 5': 4}},
#    {'id': 6,
#     'slide_obj': <pptx.slide.SlideLayout at 0x2cf835796d0>,
#     'placeholders': {'Segnaposto numero diapositiva 5': 4,
#      'Text Placeholder 8': 10}}]},
#  {'layout_id': 2,
#   'slides': [{'id': 0,
#     'slide_obj': <pptx.slide.SlideLayout at 0x2cf835792d0>,
#     'placeholders': {'Segnaposto titolo 1': 0,
#      'Segnaposto testo 2': 1,
#      'Segnaposto numero diapositiva 5': 4}},
#    {'id': 1,
#     'slide_obj': <pptx.slide.SlideLayout at 0x2cf83579910>,
#     'placeholders': {'Segnaposto titolo 1': 0,
#      'Segnaposto testo 2': 1,
#      'Segnaposto numero diapositiva 5': 4}},
#    {'id': 2,
#     'slide_obj': <pptx.slide.SlideLayout at 0x2cf83579a50>,
#     'placeholders': {'Segnaposto titolo 1': 0,
#      'Segnaposto numero diapositiva 5': 4}},
#    {'id': 3,
#     'slide_obj': <pptx.slide.SlideLayout at 0x2cf83579b90>,
#     'placeholders': {'Segnaposto titolo 1': 0,
#      'Segnaposto testo 2': 1,
#      'Segnaposto numero diapositiva 5': 4}},
#    {'id': 4,
#     'slide_obj': <pptx.slide.SlideLayout at 0x2cf83579bd0>,
#     'placeholders': {'Segnaposto titolo 1': 0,
#      'Segnaposto numero diapositiva 5': 4}},
#    {'id': 5,
#     'slide_obj': <pptx.slide.SlideLayout at 0x2cf83579c90>,
#     'placeholders': {'Segnaposto numero diapositiva 5': 4}}]},
#  {'layout_id': 3,
#   'slides': [{'id': 0,
#     'slide_obj': <pptx.slide.SlideLayout at 0x2cf83579350>,
#     'placeholders': {'Segnaposto numero diapositiva 5': 4}}]},
#  {'layout_id': 4,
#   'slides': [{'id': 0,
#     'slide_obj': <pptx.slide.SlideLayout at 0x2cf83579d50>,
#     'placeholders': {'Segnaposto titolo 1': 0,
#      'Segnaposto testo 2': 1,
#      'Segnaposto numero diapositiva 5': 4}},
#    {'id': 1,
#     'slide_obj': <pptx.slide.SlideLayout at 0x2cf83579750>,
#     'placeholders': {'Segnaposto titolo 1': 0,
#      'Segnaposto testo 2': 1,
#      'Segnaposto numero diapositiva 5': 4}},
#    {'id': 2,
#     'slide_obj': <pptx.slide.SlideLayout at 0x2cf83579fd0>,
#     'placeholders': {'Segnaposto titolo 1': 0,
#      'Segnaposto numero diapositiva 5': 4}},
#    {'id': 3,
#     'slide_obj': <pptx.slide.SlideLayout at 0x2cf83579950>,
#     'placeholders': {'Segnaposto titolo 1': 0,
#      'Segnaposto testo 2': 1,
#      'Segnaposto numero diapositiva 5': 4}},
#    {'id': 4,
#     'slide_obj': <pptx.slide.SlideLayout at 0x2cf83579e10>,
#     'placeholders': {'Segnaposto titolo 1': 0,
#      'Segnaposto numero diapositiva 5': 4}},
#    {'id': 5,
#     'slide_obj': <pptx.slide.SlideLayout at 0x2cf8357a190>,
#     'placeholders': {'Segnaposto numero diapositiva 5': 4}}]},
#  {'layout_id': 5,
#   'slides': [{'id': 0,
#     'slide_obj': <pptx.slide.SlideLayout at 0x2cf83579f10>,
#     'placeholders': {'Titolo 1': 0}}]},
#  {'layout_id': 6,
#   'slides': [{'id': 0,
#     'slide_obj': <pptx.slide.SlideLayout at 0x2cf8357a450>,
#     'placeholders': {'Titolo 1': 0, 'Segnaposto numero diapositiva 5': 4}}]},
#  {'layout_id': 7,
#   'slides': [{'id': 0,
#     'slide_obj': <pptx.slide.SlideLayout at 0x2cf8357a650>,
#     'placeholders': {'Segnaposto titolo 1': 0,
#      'Segnaposto testo 2': 1,
#      'Segnaposto numero diapositiva 5': 4}},
#    {'id': 1,
#     'slide_obj': <pptx.slide.SlideLayout at 0x2cf8357a510>,
#     'placeholders': {'Segnaposto titolo 1': 0,
#      'Segnaposto testo 2': 1,
#      'Segnaposto numero diapositiva 5': 4}},
#    {'id': 2,
#     'slide_obj': <pptx.slide.SlideLayout at 0x2cf8357a7d0>,
#     'placeholders': {'Segnaposto titolo 1': 0,
#      'Segnaposto numero diapositiva 5': 4}},
#    {'id': 3,
#     'slide_obj': <pptx.slide.SlideLayout at 0x2cf8357a890>,
#     'placeholders': {'Segnaposto titolo 1': 0,
#      'Segnaposto testo 2': 1,
#      'Segnaposto numero diapositiva 5': 4}},
#    {'id': 4,
#     'slide_obj': <pptx.slide.SlideLayout at 0x2cf8357a8d0>,
#     'placeholders': {'Segnaposto titolo 1': 0,
#      'Segnaposto numero diapositiva 5': 4}}]},
#  {'layout_id': 8,
#   'slides': [{'id': 0,
#     'slide_obj': <pptx.slide.SlideLayout at 0x2cf8357aa50>,
#     'placeholders': {'Segnaposto titolo 1': 0,
#      'Segnaposto testo 2': 1,
#      'Segnaposto numero diapositiva 5': 4}},
#    {'id': 1,
#     'slide_obj': <pptx.slide.SlideLayout at 0x2cf8357aa10>,
#     'placeholders': {'Segnaposto titolo 1': 0,
#      'Segnaposto testo 2': 1,
#      'Segnaposto numero diapositiva 5': 4}},
#    {'id': 2,
#     'slide_obj': <pptx.slide.SlideLayout at 0x2cf8357ab50>,
#     'placeholders': {'Segnaposto titolo 1': 0,
#      'Segnaposto numero diapositiva 5': 4}}]},
#  {'layout_id': 9,
#   'slides': [{'id': 0,
#     'slide_obj': <pptx.slide.SlideLayout at 0x2cf8357ac10>,
#     'placeholders': {'Segnaposto titolo 4': 0,
#      'Segnaposto numero diapositiva 5': 4}}]}]

# %%
# Extract the slide based on particular id
def get_slide(layout_id,slide_id):
    layout = next((item for item in a if item['layout_id'] == layout_id), None)
    
    if layout:
    
        slide = next((slide for slide in layout['slides'] if slide['id'] == slide_id), None)
        if slide:
            slide_obj = slide['slide_obj']
            print(f"Slide object with id : {slide_obj}")
        else:
            print("Slide with id 6 not found")
    else:
        print("Layout with layout_id 1 not found")
    return slide
get_slide(1,6)
# Out:
# Slide object with id : <pptx.slide.SlideLayout object at 0x000002CF835796D0>
# {'id': 6,
#  'slide_obj': <pptx.slide.SlideLayout at 0x2cf835796d0>,
#  'placeholders': {'Segnaposto numero diapositiva 5': 4,
#   'Text Placeholder 8': 10}}

# %%
new_ppt=Presentation("updated-master.pptx")

# %%
with open("resp.txt", 'r', encoding='utf-8') as f:
            for line_num, line in enumerate(f):
                print(line)
# Out:
# #Title: Recordatti Presentation
#
# #Slide: 1
#
# #Header: Table of Contents
#
# #Content:Introduction
#
# Main Content
#
# Summary
#
# #Slide: 2
#
# #Header: Introduction
#
# #Content: CONTENT OF THE SLIDE
#
# This is the content of the intro slide.
#
# #Slide: 3
#
# #Header:  Main Content
#
# #Content: CONTENT OF THE SLIDE
#
# This is the content of the main slide.
#
# #Slide: 4
#
# #Header: Summary
#
# #Content: CONTENT OF THE SUMMARY

# %%
#  Parse slide contents and map it then use that loop through that map and select the content and

# %%
new_ppt=Presentation("updated-master.pptx")
from pptx.util import Inches, Pt
from pptx.enum.shapes import MSO_SHAPE
from pptx.dml.color import RGBColor

# %%
def remove_numbers(text):
    return re.sub(r'^\d+\.\s*', '', text)

# %%
def parse_text_data(text):
    slides = []
    slide = {}
    lines = text.strip().split('\n')
    
    for line in lines:
        if line.startswith("#Title:"):
            title = line.replace("#Title:", "").strip()
            slide['title'] = title
        elif line.startswith("#Slide:"):
            if slide:
                slides.append(slide)
                slide = {}
            slide_number = line.replace("#Slide:", "").strip()
            slide['slide_number'] = slide_number
        elif line.startswith("#Header:") or line.startswith("#Headers:"):
            header = line.replace("#Header:", "").replace("#Headers:", "").strip()
            slide['header'] = header
        elif line.startswith("#Content:"):
            content = line.replace("#Content:", "").strip()
            slide['content'] = content
        else:
            if 'content' in slide:
                slide['content'] += '\n' + line.strip()
    
    if slide:
        slides.append(slide)
    
    return slides

# %%
# Function to create PowerPoint presentation
def create_presentation(slides, output_file):
   
    #  Title Slide
    ref_slide=get_slide(5,0)
    title_placeholder_index=ref_slide['placeholders']['Titolo 1']
    slide = new_ppt.slides.add_slide(ref_slide['slide_obj'])
    title = slide.placeholders[title_placeholder_index]
    title.text = slides[0]['title']
    
    # ref_slide=get_slide(1,6)
    # slide = new_ppt.slides.add_slide(ref_slide['slide_obj'])
    # title_placeholder_index=ref_slide['placeholders']['Text Placeholder 8']
    # title = slide.placeholders[title_placeholder_index]
    # title.text = slides[1]['header']

   
 

    
     
    # Add other slides
    for slide_data in slides[1:]:
        ref_slide =get_slide(1,0)
        print(ref_slide)
        
        slide = new_ppt.slides.add_slide(ref_slide['slide_obj'])
        title_placeholder_index=ref_slide['placeholders']['Segnaposto titolo 1']
        # content = slide.placeholders[1]
        content_placeholder_index=ref_slide['placeholders']['Text Placeholder 4']
        title = slide.placeholders[title_placeholder_index]
                        
        content=slide.placeholders[content_placeholder_index]
        # slide_number=slide.placeholders[slide_number_placeholder_index]
        title.text = slide_data['header']
        if "table of contents" in slide_data['header'].lower():
    
            content.text = ""  # Clear the content placeholder text
            lines = slide_data['content'].split('\n')
            bullet_color = RGBColor(255, 0, 0)
            left = Inches(0.5)
            top = Inches(1)
            width = Inches(8.5)
            height = Inches(5.5)
            textbox = slide.shapes.add_textbox(left, top, width, height)
            text_frame = textbox.text_frame
            print(lines)
            for idx, line in enumerate([remove_numbers(line) for line in lines]):

                if(line.strip()!=''):
                
                     p = text_frame.add_paragraph()
                     p.level = 0  # Bullet point level
                     p.font.size = Pt(18)
                     p.font.color.rgb = RGBColor(0, 0, 0)
                     p.alignment = PP_ALIGN.LEFT
                    
                        # Add a custom bullet at the beginning
                     run = p.add_run()
                     run.text = '\u25BA'  # Unicode character for a triangle
                     run.font.color.rgb = bullet_color
                     run.font.size = Pt(18)
                     run.font.bold = True
                
                    # Add the text after the bullet
                     print(idx)
                     run = p.add_run()
                     run.text = ' ' + line.strip()
                     run.font.color.rgb = RGBColor(0, 0, 0)
                     run.font.size = Pt(18)
                                
               
        else:
            content.text = slide_data['content']

        # slide_number.text=slide_data['slide_number']
    # Add end Slide

    ref_slide =get_slide(0,7)
    print(ref_slide)
        
    slide = new_ppt.slides.add_slide(ref_slide['slide_obj'])
    
    
    # Save the presentation
    
    new_ppt.save(output_file)

    print(f"PowerPoint presentation created successfully and saved as {output_file}.")

# Function to read the text file and generate the presentation

# %%
def generate_presentation_from_file(file_path, output_file):
    with open(file_path, 'r') as file:
        text_data = file.read()
    
    slides = parse_text_data(text_data)
    print(slides)
    create_presentation(slides, output_file)

generate_presentation_from_file("Generated_text.txt", "gen.pptx")
# Out:
# [{'title': '24 WEEK STUDY ON LEBRIKIZUMAB'}, {'slide_number': '1', 'header': 'Table of Contents', 'content': '1. Study Objective\n2. Primary Outcome Measures\n3. Secondary Outcome Measures\n4. Study Details\n5. Source Reference\n'}, {'slide_number': '2', 'header': 'Study Objective', 'content': 'Investigate safety and efficacy of Lebrikizumab in moderate-to-severe atopic dermatitis patients with skin of color.\n'}, {'slide_number': '3', 'header': 'Primary Outcome Measures', 'content': 'Percentage of participants achieving EASI-75 (>75% reduction) from baseline to week 16.\n'}, {'slide_number': '4', 'header': 'Secondary Outcome Measures', 'content': 'Includes achieving EASI-75 at week 24, IGA score improvement, total EASI change, EASI-90 achievement, and Pruritus NRS reduction.\n'}, {'slide_number': '5', 'header': 'Summary', 'content': 'The 24-week study on Lebrikizumab aims to assess its safety and efficacy in atopic dermatitis patients, with various outcome measures focused on disease improvement.'}]
# Slide object with id : <pptx.slide.SlideLayout object at 0x000002CF83579F10>
# Slide object with id : <pptx.slide.SlideLayout object at 0x000002CF83578CD0>
# {'id': 0, 'slide_obj': <pptx.slide.SlideLayout object at 0x000002CF83578CD0>, 'placeholders': {'Segnaposto titolo 1': 0, 'Segnaposto numero diapositiva 5': 4, 'Text Placeholder 4': 10}}
# ['1. Study Objective', '2. Primary Outcome Measures', '3. Secondary Outcome Measures', '4. Study Details', '5. Source Reference', '']
# 0
# 1
# 2
# 3
# 4
# Slide object with id : <pptx.slide.SlideLayout object at 0x000002CF83578CD0>
# {'id': 0, 'slide_obj': <pptx.slide.SlideLayout object at 0x000002CF83578CD0>, 'placeholders': {'Segnaposto titolo 1': 0, 'Segnaposto numero diapositiva 5': 4, 'Text Placeholder 4': 10}}
# Slide object with id : <pptx.slide.SlideLayout object at 0x000002CF83578CD0>
# {'id': 0, 'slide_obj': <pptx.slide.SlideLayout object at 0x000002CF83578CD0>, 'placeholders': {'Segnaposto titolo 1': 0, 'Segnaposto numero diapositiva 5': 4, 'Text Placeholder 4': 10}}
# Slide object with id : <pptx.slide.SlideLayout object at 0x000002CF83578CD0>
# {'id': 0, 'slide_obj': <pptx.slide.SlideLayout object at 0x000002CF83578CD0>, 'placeholders': {'Segnaposto titolo 1': 0, 'Segnaposto numero diapositiva 5': 4, 'Text Placeholder 4': 10}}
# Slide object with id : <pptx.slide.SlideLayout object at 0x000002CF83578CD0>
# {'id': 0, 'slide_obj': <pptx.slide.SlideLayout object at 0x000002CF83578CD0>, 'placeholders': {'Segnaposto titolo 1': 0, 'Segnaposto numero diapositiva 5': 4, 'Text Placeholder 4': 10}}
# Slide object with id : <pptx.slide.SlideLayout object at 0x000002CF83578F10>
# {'id': 7, 'slide_obj': <pptx.slide.SlideLayout object at 0x000002CF83578F10>, 'placeholders': {}}
# PowerPoint presentation created successfully and saved as gen.pptx.

# %%
from openai import AsyncOpenAI, OpenAIError
import re

# %%
# Connect with LLM $ pLACEHOLDERS DYNAMIC # table of contents alignment. # Check why the downloaded PPt is throwing the error
openai_client=AsyncOpenAI(
        )
print(openai_client)
messages= [
        {
            "content": "What does the 24 week study on Lebrikizumab show?",
            "role": "user"
        },
        {
            "content": "<h2>24 Week Study on Lebrikizumab</h2>\n<p>The 24-week study aims to investigate the safety and efficacy of Lebrikizumab in adolescent and adult participants with moderate-to-severe atopic dermatitis (AD) and skin of color. The main purpose of this study is to determine the safety and efficacy of Lebrikizumab in this population. </p>\n\n<p>Participants will receive Lebrikizumab subcutaneously (SC). The primary outcome measures include the percentage of participants achieving Eczema Area and Severity Index-75 (EASI-75) (>75% reduction from baseline in EASI) from baseline to week 16. </p>\n\n<p>The secondary outcome measures include:</p>\n<ul>\n  <li>Percentage of participants achieving a >75% reduction from baseline in EASI-75 from baseline to week 24.</li>\n  <li>Percentage of participants with an Investigator's Global Assessment (IGA) score of 0 or 1 and a reduction ≥2 points from baseline from baseline to week 16 and 24.</li>\n  <li>Percentage change from baseline in total EASI at week 16 and 24.</li>\n  <li>Percentage of participants achieving a >90% reduction from baseline in EASI-90 from baseline to week 16 and 24.</li>\n  <li>Percentage of participants with a Pruritus Numeric Rating Scale (NRS) of ≥4 points at baseline who achieve a 4-point reduction from baseline from baseline to week 16 and 24.</li>\n</ul>\n\n<p>The study is currently in the recruiting phase with an anticipated enrollment of 80 participants. The primary completion date is expected to be March 1, 2024, and the study completion date is anticipated to be August 15, 2024.</p>\n\n<p>Source(s): <a href=\"Ref0.pdf\">Ref0.pdf</a></p>",
            "role": "assistant"
        }
    ]
# Out:
# <openai.AsyncOpenAI object at 0x000002CF867E1510>

# %%
def get_system_message():
        return """Write a presentation/powerpoint about the user's topic. You'll be provided the chat history and the user's topic. Only use the chat history and the user's topic to write the presentation.
You only answer with the presentation. Follow the structure of the example.
Notice
-You do all the presentation text for the user.
-You write the texts no longer than 250 characters!
-You make very short titles!
-You make the presentation easy to understand.
-The presentation has a table of contents.
-The presentation has a summary.
-At max 5 slides.

Example! - Stick to this formatting exactly!
#Title: TITLE OF THE PRESENTATION

#Slide: 1
#Header: table of contents
#Content: 1. CONTENT OF THIS POWERPOINT
2. CONTENTS OF THIS POWERPOINT
3. CONTENT OF THIS POWERPOINT
...

#Slide: 2
#Header: TITLE OF SLIDE
#Content: CONTENT OF THE SLIDE

#Slide: 3
#Header: TITLE OF SLIDE
#Content: CONTENT OF THE SLIDE

#Slide: 4
#Header: TITLE OF SLIDE
#Content: CONTENT OF THE SLIDE

#Slide: 5
#Headers: summary
#Content: CONTENT OF THE SUMMARY

#Slide: END"""

# %%
async def create_ppt_text(input, messages):
        print(input)
        # Take only the latest 2 conversationsCan
        messages = messages[-4:]
        print(messages)
        history = """"""
        for i in range(len(messages)):
            message_content = messages[i].get('content')
            message_content_cleaned = re.sub(r'<a[^>]*>(.*?)</a>', r'\1', message_content)

            history += f"""{messages[i].get('role')}: {message_content_cleaned}"""
            history += "\n"

        message = f"""The user wants a presentation about "{input}"

History:
{history}
"""

        response = openai_client.chat.completions.create(
            model="gpt-3.5-turbo",
            messages=[
                {"role": "system", "content": get_system_message()},
                {"role": "user", "content": message}
            ],
            temperature=0.5,
        )

        chat_coroutine_result = await response
        chat_resp = chat_coroutine_result.model_dump()
        print(chat_resp)
        return chat_resp["choices"][0]["message"]["content"]

# %%
async def generate_ppt():
        input_string = messages[0].get('content')
        
         

        # filename = self.sanitize_filename(f"{input_string}.txt")
        # file_path = os.path.join(cache_dir, filename)

        with open("Generated_text.txt", 'w', encoding='utf-8') as f:
            ppt_text = await create_ppt_text(input_string, messages)
            f.write(ppt_text)
        return "Generated Text"

# %%
result = await generate_ppt()
print(result)
# Out:
# What does the 24 week study on Lebrikizumab show?
# [{'content': 'What does the 24 week study on Lebrikizumab show?', 'role': 'user'}, {'content': '<h2>24 Week Study on Lebrikizumab</h2>\n<p>The 24-week study aims to investigate the safety and efficacy of Lebrikizumab in adolescent and adult participants with moderate-to-severe atopic dermatitis (AD) and skin of color. The main purpose of this study is to determine the safety and efficacy of Lebrikizumab in this population. </p>\n\n<p>Participants will receive Lebrikizumab subcutaneously (SC). The primary outcome measures include the percentage of participants achieving Eczema Area and Severity Index-75 (EASI-75) (>75% reduction from baseline in EASI) from baseline to week 16. </p>\n\n<p>The secondary outcome measures include:</p>\n<ul>\n  <li>Percentage of participants achieving a >75% reduction from baseline in EASI-75 from baseline to week 24.</li>\n  <li>Percentage of participants with an Investigator\'s Global Assessment (IGA) score of 0 or 1 and a reduction ≥2 points from baseline from baseline to week 16 and 24.</li>\n  <li>Percentage change from baseline in total EASI at week 16 and 24.</li>\n  <li>Percentage of participants achieving a >90% reduction from baseline in EASI-90 from baseline to week 16 and 24.</li>\n  <li>Percentage of participants with a Pruritus Numeric Rating Scale (NRS) of ≥4 points at baseline who achieve a 4-point reduction from baseline from baseline to week 16 and 24.</li>\n</ul>\n\n<p>The study is currently in the recruiting phase with an anticipated enrollment of 80 participants. The primary completion date is expected to be March 1, 2024, and the study completion date is anticipated to be August 15, 2024.</p>\n\n<p>Source(s): <a href="Ref0.pdf">Ref0.pdf</a></p>', 'role': 'assistant'}]
# {'id': 'chatcmpl-9o7lonkTPe1lnDwP4KUCLDOGq5qPy', 'choices': [{'finish_reason': 'stop', 'index': 0, 'logprobs': None, 'message': {'content': '#Title: 24 WEEK STUDY ON LEBRIKIZUMAB\n\n#Slide: 1\n#Header: Table of Contents\n#Content: 1. Study Objective\n2. Primary Outcome Measures\n3. Secondary Outcome Measures\n4. Study Details\n5. Source Reference\n\n#Slide: 2\n#Header: Study Objective\n#Content: Investigate safety and efficacy of Lebrikizumab in moderate-to-severe atopic dermatitis patients with skin of color.\n\n#Slide: 3\n#Header: Primary Outcome Measures\n#Content: Percentage of participants achieving EASI-75 (>75% reduction) from baseline to week 16.\n\n#Slide: 4\n#Header: Secondary Outcome Measures\n#Content: Includes achieving EASI-75 at week 24, IGA score improvement, total EASI change, EASI-90 achievement, and Pruritus NRS reduction.\n\n#Slide: 5\n#Header: Summary\n#Content: The 24-week study on Lebrikizumab aims to assess its safety and efficacy in atopic dermatitis patients, with various outcome measures focused on disease improvement.', 'role': 'assistant', 'function_call': None, 'tool_calls': None}}], 'created': 1721733296, 'model': 'gpt-3.5-turbo-0125', 'object': 'chat.completion', 'service_tier': None, 'system_fingerprint': None, 'usage': {'completion_tokens': 239, 'prompt_tokens': 726, 'total_tokens': 965}}
# Generated Text
